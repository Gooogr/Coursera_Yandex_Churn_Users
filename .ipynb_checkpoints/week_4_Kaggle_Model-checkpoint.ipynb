# %%
import pandas as pd
pd.set_option('display.max_columns', 250)

import numpy as np

# from scipy.sparse import coo_matrix, csr_matrix, hstack

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import scikitplot as skplt

#Imputers
# from impyute.imputation.cs import mice, fast_knn 
from sklearn.impute import SimpleImputer

#Encoders
import category_encoders as ce

from sklearn import metrics
from sklearn.metrics import roc_curve, confusion_matrix


#For pipelines creating
from sklearn.base import TransformerMixin, BaseEstimator
from sklearn.pipeline import Pipeline, FeatureUnion, _transform_one
from sklearn.preprocessing import FunctionTransformer
from sklearn.externals.joblib import Parallel, delayed

from sklearn.model_selection import train_test_split, StratifiedKFold, KFold

from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LogisticRegression
from catboost import CatBoostClassifier


# import itertools
# import pickle

# %%
SEED = 42

# %%
# https://signal-to-noise.xyz/post/sklearn-pipeline/

class DFFeatureUnion(FeatureUnion):
    def fit_transform(self, X, y=None, **fit_params):
        # non-optimized default implementation; override when a better
        # method is possible
        if y is None:
            # fit method of arity 1 (unsupervised transformation)
            return self.fit(X, **fit_params).transform(X)
        else:
            # fit method of arity 2 (supervised transformation)
            return self.fit(X, y, **fit_params).transform(X)

    def transform(self, X):
        Xs = Parallel(n_jobs=self.n_jobs)(
#             delayed(_transform_one)(trans, weight, X) #original
            delayed(_transform_one)(trans, X, None, weight)
            for name, trans, weight in self._iter())
        return pd.concat(Xs, axis=1, join='inner')

# %%
class DataFrameSelector(BaseEstimator, TransformerMixin):
    '''
    Используется для выбора сегментов датафрейма с помощью листа названий признаков
    '''
    
    def __init__(self, attribute_names):
        self.attribute_names = attribute_names
        
    def fit(self, X, y = None):
        return self
    
    def transform(self, X):
        return X[self.attribute_names]

# %%
def train_model_cv_cl(X_train, y_train, X_test, params, 
                      encoder = None, 
                      model_type = 'sklearn', eval_metric = 'auc', 
                      sk_model = None, 
                      n_folds = 5,
                      n_estimators = 1000,
                      n_jobs = -1,
                      verbose = 250,
                      early_stopping_rounds = 200
                     ):
    if encoder is not None:
        X_train = encoder.fit_transform(X_train, y_train)
        X_test = encoder.transform(X_test)
    
    # set up scoring parameters for different models
    metrics_dict = {'auc': {'lgb': 'auc',         
                            'cat': 'AUC',
                            'sklearn': metrics.roc_auc_score,
                            'xgb': 'auc'}  
                   }
    cv_scores = []
    result_dict = {}
    pred_test = np.zeros(X_test.shape[0])
    pred_train = np.zeros(X_train.shape[0]) #collect all validation predictions over all folds
    
    fold_method = StratifiedKFold(n_splits = n_folds, shuffle = True, random_state = SEED)
    for fold_n, (dev_index, val_index) in enumerate(fold_method.split(X_train, y_train)):
        try: #if data scr or numpy matrices
            X_dev, X_val = X_train[dev_index], X_train[val_index]
            y_dev, y_val = y_train[dev_index], y_train[val_index]
            
        except: #if x data is pandas dataframes
            X_dev, X_val = X_train.iloc[dev_index], X_train.iloc[val_index]
            y_dev, y_val = y_train[dev_index], y_train[val_index]
              
        if model_type == 'sklearn':
            model = sk_model(**params)
            model.fit(X_dev, y_dev)
            pred_y_val = model.predict_proba(X_val)[:, 1]
            pred_y_test = model.predict_proba(X_test)[:, 1]
            
            score = metrics_dict[eval_metric][model_type](y_val, pred_y_val)
            print(f'Fold {fold_n}. {eval_metric}: {score:.6f}.')
            #print('')
            
        if model_type == 'lgb':
            model = lgb.LGBMClassifier(**params, n_estimators=n_estimators, n_jobs = n_jobs)
            model.fit(X_dev, y_dev, eval_set = [(X_val, y_val)], 
                      eval_metric = metrics_dict[eval_metric][model_type],
                      verbose=verbose, 
                      early_stopping_rounds=early_stopping_rounds)
            pred_y_val = model.predict_proba(X_val)[:, 1]
            pred_y_test = model.predict_proba(X_test, num_iteration=model.best_iteration_)[:, 1]
            
        if model_type == 'xgb':
            dev_data = xgb.DMatrix(data = X_dev, label = y_dev)
            valid_data = xgb.DMatrix(data = X_val, label = y_val)            
            watchlist = [(dev_data, 'dev_data'), (valid_data, 'valid_data')]
            
            param = params #outside parameters
            param['eval_metric'] = metrics_dict[eval_metric][model_type] #add parameter from metric_dict
            
            model = xgb.train(dtrain = dev_data, evals=watchlist,
                              num_boost_round = n_estimators, 
                              early_stopping_rounds=early_stopping_rounds, 
                              verbose_eval=verbose, params=params)            
            pred_y_val = model.predict(xgb.DMatrix(X_val), ntree_limit=model.best_ntree_limit)
            pred_y_test = model.predict(xgb.DMatrix(X_test), ntree_limit=model.best_ntree_limit)
            
        if model_type == 'cat':
            model = CatBoostClassifier(iterations=n_estimators, eval_metric=metrics_dict[eval_metric][model_type], **params,
                                      loss_function='Logloss', od_wait = early_stopping_rounds)
            model.fit(X_dev, y_dev, eval_set=(X_val, y_val), use_best_model=True, verbose=verbose)
            pred_y_val = model.predict_proba(X_val)[:, 1]
            pred_y_test = model.predict_proba(X_test)[:, 1]
            
        
        pred_train[val_index] += pred_y_val
        pred_test += pred_y_test
        cv_scores.append(metrics_dict[eval_metric]['sklearn'](y_val, pred_y_val))
        
    pred_test /= n_folds
    result_dict['predictions'] = pred_test
    result_dict['overall_val_predictions'] = pred_train
    result_dict['cv_scores'] = cv_scores
    
    print('CV mean score: {0:.6f}, std: {1:.6f}.'.format(np.mean(cv_scores), np.std(cv_scores)))
    
    return result_dict

# %% [markdown]
# ## Загрузка данных

# %%
churn_data_train = pd.read_csv('./Data/kaggle_data/orange_small_churn_train_data.csv')
churn_data_test = pd.read_csv('./Data/kaggle_data/orange_small_churn_test_data.csv')

# %%
churn_data_train['labels'] = churn_data_train['labels'] > 0 #convert (-1, 1) to (True, False)

# %%
churn_data_train.head()
# Out:
#    ID  Var1  Var2  Var3  Var4  Var5    Var6  Var7  Var8  Var9  Var10  Var11  \
# 0   0   NaN   NaN   NaN   NaN   NaN  3052.0   NaN   NaN   NaN    NaN    NaN
# 1   1   NaN   NaN   NaN   NaN   NaN  1813.0   7.0   NaN   NaN    NaN    NaN
# 2   2   NaN   NaN   NaN   NaN   NaN  1953.0   7.0   NaN   NaN    NaN    NaN
# 3   3   NaN   NaN   NaN   NaN   NaN  1533.0   7.0   NaN   NaN    NaN    NaN
# 4   4   NaN   NaN   NaN   NaN   NaN   686.0   7.0   NaN   NaN    NaN    NaN
#
#    Var12  Var13  Var14  Var15  Var16  Var17  Var18  Var19  Var20  Var21  \
# 0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  480.0
# 1    NaN  636.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN  212.0
# 2    NaN  448.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN  176.0
# 3    NaN    4.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN  332.0
# 4    NaN    0.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
NaN     0.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1     NaN     0.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     0.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN     0.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     0.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#    Var189  Var190 Var191      Var192            Var193 Var194 Var195 Var196  \
# 0     NaN     NaN    NaN  NESt0G8EIb           AERks4l    NaN   taul   1K8T
# 1   276.0     NaN    NaN  P1WvyxLp3Z           2Knk1KF    NaN   taul   1K8T
# 2     NaN     NaN    NaN  FoxgUHSK8h  LrdZy8QqgUfkVShG    NaN   taul   1K8T
# 3     NaN     NaN    NaN  vNEvyxLp3Z              RO12    NaN   taul   1K8T
# 4     NaN     NaN    NaN  4e7gUH7IEC              RO12    NaN   taul   1K8T
#
#   Var197   Var198      Var199   Var200 Var201 Var202 Var203 Var204   Var205  \
# 0   0LaQ  UaKK0yW  I1sFbv_0IT      NaN    NaN   EkHG   9_Y1   k13i     09_Q
# 1   YFAj  Bnunsla     o64y9zI  DlISMzi    NaN   JDd6   9_Y1   FbIm     VpdQ
# 2   TyGl  fhk21Ss  nQUveAzAF7      NaN    NaN   dnwD   9_Y1   mTeA     VpdQ
# 3   0Xwj  uoZk2Zj  LWyxgtXeJL      NaN    NaN   CwmB   F3hy   vzJD     VpdQ
# 4   vSNn  kugYdIL  ZIXKpoNpqq      NaN    NaN   625Z   9_Y1   m_h1  sJzTlal
#
#   Var206                  Var207 Var208  Var209 Var210 Var211         Var212  \
# 0   IYzP  GjJ35utlTa_GNSvxxpb9ju   kIsH     NaN   uKAI   L84s     JBfYVit4g8
# 1   haYg              me75fM6ugJ   kIsH     NaN   uKAI   L84s  XfqtO3UdzaXh_
# 2   hAFG     7M47J5GA0pTYIFxg5uy   kIsH     NaN   uKAI   L84s  4kVnq_T26xq1p
# 3   IYzP              me75fM6ugJ   kIsH     NaN   uKAI   L84s        NhsEn4L
# 4   zm5i              me75fM6ugJ   kIsH     NaN   uKAI   L84s        NhsEn4L
#
#   Var213   Var214 Var215   Var216 Var217 Var218 Var219   Var220   Var221  \
# 0    NaN      NaN    NaN  TDctq2l   KmRo   cJvF   FzaX  hLKtJ9p  Al6ZaUT
# 1    NaN  I_mbgcr    NaN  XTbqizz   qMoY   cJvF   FzaX  hN8KpA1     oslk
# 2    NaN      NaN    NaN  pMWBUmQ   qLXr   UYBR   FzaX  4UxGlow     zCkv
# 3    NaN      NaN    NaN  kZJtVhC   JC0e   cJvF   FzaX  ylCK5YS     oslk
# 4    NaN      NaN    NaN  NGZXfGp   064o   cJvF   FzaX  PYpzAu9     oslk
#
#     Var222      Var223 Var224 Var225 Var226   Var227         Var228 Var229  \
# 0  vr93T2a  LM8l689qOp    NaN    NaN   fKCe  02N6s8f  xwM2aC7IdeMC0    NaN
# 1  6hQ9lNX  LM8l689qOp    NaN   ELof   xb3V     RAYp        55YFVY9   mj86
# 2  catzS2D  LM8l689qOp    NaN    NaN   FSa2     ZI9m  ib5G6X1eUxUn6   mj86
# 3  e4lqvY0  LM8l689qOp    NaN    NaN   xb3V     RAYp  F2FyR07IdsN7I    NaN
# 4  MAz3HNj  LM8l689qOp    NaN    NaN   WqMG     RAYp  F2FyR07IdsN7I    NaN
#
#    Var230  labels
# 0     NaN   False
# 1     NaN   False
# 2     NaN   False
# 3     NaN    True
# 4     NaN   False

# %%
churn_data_test.head()
# Out:
#    ID  Var1  Var2  Var3  Var4  Var5    Var6  Var7  Var8  Var9  Var10  Var11  \
# 0   0   NaN   NaN   NaN   NaN   NaN  1225.0   7.0   NaN   NaN    NaN    NaN
NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN   22015.0     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN  337120.0     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN       NaN     NaN     NaN     NaN
#
#        Var153     Var154  Var155  Var156  Var157  Var158  Var159  Var160  \
# 0  10278280.0        NaN     NaN     NaN     NaN     NaN     NaN    28.0
# 1    777520.0        NaN     NaN     NaN     NaN     NaN     NaN    28.0
# 2   5667840.0        NaN     NaN     NaN     NaN     NaN     NaN    40.0
# 3  10506480.0        NaN     NaN     NaN     NaN     NaN     NaN    58.0
# 4         NaN  1283808.0     NaN    98.0     NaN     NaN     NaN     NaN
#
#    Var161  Var162    Var163  Var164  Var165  Var166  Var167  Var168  Var169  \
# 0     NaN     NaN       0.0     NaN     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN   73218.0     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN   25296.0     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN  467196.0     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN       NaN     NaN     NaN     NaN     NaN  280.08     NaN
#
#    Var170  Var171  Var172  Var173  Var174  Var175  Var176  Var177  Var178  \
# 0     NaN     NaN     NaN     0.0     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     0.0     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     0.0     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     0.0     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#    Var179     Var180  Var181  Var182  Var183  Var184  Var185  Var186  Var187  \
# 0     NaN        NaN     0.0     NaN     NaN     NaN     NaN     NaN     NaN
# 1     NaN        NaN     0.0     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN        NaN    14.0     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN        NaN     0.0     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN  2892911.0     NaN     NaN     NaN     NaN     NaN     0.0     2.0
#
#    Var188  Var189  Var190 Var191      Var192   Var193 Var194 Var195 Var196  \
# 0     NaN     NaN     NaN    NaN  P1WvyxLp3Z  2Knk1KF    NaN   taul   1K8T
# 1     NaN     NaN     NaN    NaN  bZkvyxLkBI     RO12    NaN   taul   1K8T
# 2     NaN     NaN     NaN    NaN  75lTmBtFkL     RO12   SEuy   taul   1K8T
# 3     NaN     NaN     NaN    NaN  YddTmBtueT     RO12   SEuy   taul   1K8T
# 4     NaN     NaN     NaN    NaN  mCGq9ayE15     RO12    NaN   taul   1K8T
#
#   Var197   Var198      Var199   Var200 Var201 Var202 Var203 Var204 Var205  \
# 0   0Xwj  PHNvXy8  xUOdRmdN20  IBm9AvG    NaN   skcI   HLqf   vzJD    NaN
# 1   0Xwj  6KF0k8W  V4E_TU9097      NaN    NaN   CZsd   F3hy   vzJD   09_Q
# 2   AnrR  ckoNVBU  _jTP8ioIlJ  JnrRQD4   smXZ   PwdO   9_Y1   C6Eu   VpdQ
# 3   487l  77f44U8     II0S8f9  a1lFLoc   smXZ   SOkz   9_Y1   C6Eu   VpdQ
# 4   lK27  esxkA1P  767sa0XN9l      NaN    NaN   kVZt   9_Y1   vm5R   09_Q
#
#   Var206      Var207 Var208  Var209 Var210 Var211   Var212 Var213   Var214  \
# 0   lVqb  NKv3VA1BpP   sBgB     NaN   uKAI   L84s  Ie_5MZs    NaN  xRz9wph
# 1   IYzP  me75fM6ugJ   kIsH     NaN   uKAI   L84s  NhsEn4L    NaN      NaN
# 2   sYC_  me75fM6ugJ   kIsH     NaN   uKAI   Mtgm  NhsEn4L    NaN  Iy8LM_S
# 3   IYzP  me75fM6ugJ   kIsH     NaN   uKAI   L84s  NhsEn4L    NaN  GccbB3h
# 4    NaN  me75fM6ugJ   kIsH     NaN   uKAI   Mtgm  NhsEn4L    NaN      NaN
#
#   Var215   Var216 Var217 Var218 Var219   Var220 Var221   Var222      Var223  \
# 0    NaN  CWNY2py   jgOV   UYBR   FzaX  UF16siJ   zCkv  APgdzOv  jySVZNlOJy
# 1    NaN  TDcECyH   PDRj   cJvF   FzaX  ot6oLzk   oslk  IIvC99a  LM8l689qOp
# 2    NaN  kq0aHkC   laMb   UYBR   FzaX  6VLNqhB   oslk  6YSocsg  LM8l689qOp
# 3    NaN  mAjbk_S   qLRt   UYBR   FzaX  tzp8jNM   oslk  5nQ7A2G  jySVZNlOJy
# 4   eGzu  7Wwvby0   XqfQ   UYBR   FzaX  EPImS85   oslk  MI8s5nE  LM8l689qOp
#
#   Var224 Var225 Var226 Var227         Var228 Var229  Var230
# 0    NaN   ELof   xb3V   6fzt        Zy3gnGM    NaN     NaN
# 1    NaN    NaN   xb3V   RAYp  F2FyR07IdsN7I    NaN     NaN
# 2    NaN   kG3k   rgKb   RAYp  F2FyR07IdsN7I   mj86     NaN
# 3    NaN   kG3k   rgKb   RAYp  F2FyR07IdsN7I   am7c     NaN
# 4    NaN    NaN   7P5s   RAYp  F2FyR07IdsN7I    NaN     NaN

# %%
print(churn_data_train.shape, churn_data_test.shape)
# Out:
# (18299, 232) (10000, 231)

# %%
churn_data_train.drop(columns = ['ID'], axis = 0, inplace = True)
churn_data_test.drop(columns = ['ID'], axis = 0, inplace = True)

# %% [markdown]
# Первые 190 признаков - числовые, остальные 40 - категориальные.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Первичный отбор признаков по колчеству пропущенных значений

# %% [markdown]
# Определим, есть ли в train полностью пустые столбцы.

# %%
const_feature = churn_data_train.isna().sum(axis = 0) == len(churn_data_train)
useless_features = const_feature[const_feature == True].index
print('Полностью пустые признаки: \n', useless_features.to_list())
# Out:
# Полностью пустые признаки:
#  ['Var8', 'Var15', 'Var20', 'Var31', 'Var32', 'Var39', 'Var42', 'Var48', 'Var52', 'Var55', 'Var79', 'Var141', 'Var167', 'Var169', 'Var175', 'Var185', 'Var209', 'Var230']

# %%
num_features_names = ['Var{}'.format(i) for i in range(1, 191) if 'Var{}'.format(i) not in useless_features]
cat_features_names = ['Var{}'.format(i) for i in range(191, 231) if 'Var{}'.format(i) not in useless_features]

print('Количество числовых признаков:', len(num_features_names))
print('Количество категориальных признаков:', len(cat_features_names))
# Out:
# Количество числовых признаков: 174
# Количество категориальных признаков: 38

# %%
num_data = churn_data_train.loc[:, num_features_names]
cat_data = churn_data_train.loc[:, cat_features_names]

# %% [markdown]
# **Подберем порог отбрасывания числовых признаков по количеству пустых объектов**

# %%
feature_amount = []
for threshold in range(0, 40000, 1000):
    nan_counter = num_data.isna().sum(axis = 0)
    f_amount = len(nan_counter[nan_counter < threshold])
    feature_amount.append(f_amount)

plt.figure(figsize = (10, 5))
plt.plot(range(0, 40000, 1000), feature_amount)
plt.title('Изменение количества числовых признаков в зависимости от фильтрующего порога')
plt.xlabel('Пороговое количество nan объектов')
plt.ylabel('Количество отобранных признаков')
plt.show()

# %%
NUM_THRESHOLD = 18000

# %%
nan_count = num_data.isna().sum(axis = 0).to_frame(name = 'count')
useful_num_featues = (nan_count[nan_count['count'] < NUM_THRESHOLD].index).to_list()

print(useful_num_featues)
# Out:
# ['Var2', 'Var3', 'Var4', 'Var5', 'Var6', 'Var7', 'Var10', 'Var11', 'Var13', 'Var14', 'Var16', 'Var17', 'Var18', 'Var19', 'Var21', 'Var22', 'Var23', 'Var24', 'Var25', 'Var26', 'Var27', 'Var28', 'Var34', 'Var35', 'Var36', 'Var37', 'Var38', 'Var40', 'Var43', 'Var44', 'Var46', 'Var49', 'Var51', 'Var54', 'Var57', 'Var59', 'Var60', 'Var65', 'Var67', 'Var68', 'Var69', 'Var70', 'Var71', 'Var72', 'Var73', 'Var74', 'Var75', 'Var76', 'Var78', 'Var80', 'Var81', 'Var82', 'Var83', 'Var84', 'Var85', 'Var88', 'Var91', 'Var93', 'Var94', 'Var95', 'Var96', 'Var97', 'Var99', 'Var103', 'Var104', 'Var105', 'Var106', 'Var107', 'Var109', 'Var111', 'Var112', 'Var113', 'Var114', 'Var115', 'Var117', 'Var119', 'Var120', 'Var122', 'Var123', 'Var124', 'Var125', 'Var126', 'Var127', 'Var128', 'Var130', 'Var132', 'Var133', 'Var134', 'Var135', 'Var138', 'Var139', 'Var140', 'Var143', 'Var144', 'Var145', 'Var146', 'Var147', 'Var148', 'Var149', 'Var150', 'Var152', 'Var153', 'Var155', 'Var157', 'Var159', 'Var160', 'Var161', 'Var162', 'Var163', 'Var164', 'Var166', 'Var170', 'Var171', 'Var172', 'Var173', 'Var174', 'Var176', 'Var177', 'Var179', 'Var181', 'Var182', 'Var183', 'Var184', 'Var188', 'Var189']

# %%
print('Итоговое количество отобранных числовых признаков:', len(useful_num_featues))
# Out:
# Итоговое количество отобранных числовых признаков: 125

# %% [markdown]
# **Аналогично подберем порог для категориальных признаков**

# %%
feature_amount = []
for threshold in range(0, 40000, 1000):
    nan_counter = cat_data.isna().sum(axis = 0)
    f_amount = len(nan_counter[nan_counter < threshold])
    feature_amount.append(f_amount)

plt.figure(figsize = (10, 5))
plt.plot(range(0, 40000, 1000), feature_amount)
plt.title('Изменение количества категориальных признаков в зависимости от фильтрующего порога')
plt.xlabel('Пороговое количество not nan объектов')
plt.ylabel('Количество отобранных признаков')
plt.show()

# %% [markdown]
# Обработаем все категориальные признаки

# %%
useful_cat_featues = cat_features_names

# %% [markdown]
# Сформируем итоговый список отобранных признаков

# %%
selected_features = useful_num_featues  + useful_cat_featues
print('Общее число отобранных признаков: ',  len(selected_features))
# Out:
# Общее число отобранных признаков:  163

# %% [markdown]
# ### Разбиение данных

# %%
churn_data_test.head()
# Out:
#    Var1  Var2  Var3  Var4  Var5    Var6  Var7  Var8  Var9  Var10  Var11  \
# 0   NaN   NaN   NaN   NaN   NaN  1225.0   7.0   NaN   NaN    NaN    NaN
# 1   NaN   NaN   NaN   NaN   NaN   896.0  14.0   NaN   NaN    NaN    NaN
# 2   NaN   NaN   NaN   NaN   NaN   791.0   7.0   NaN   NaN    NaN    NaN
# 3   NaN   NaN   NaN   NaN   NaN  2296.0   7.0   NaN   NaN    NaN    NaN
# 4   8.0   NaN   NaN   NaN   NaN     NaN   NaN   NaN  28.0    NaN    NaN
#
#    Var12   Var13  Var14  Var15  Var16  Var17  Var18  Var19  Var20  Var21  \
# 0    NaN  2352.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
.0     NaN     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN   73218.0     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN   25296.0     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN  467196.0     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN       NaN     NaN     NaN     NaN     NaN  280.08     NaN
#
#    Var170  Var171  Var172  Var173  Var174  Var175  Var176  Var177  Var178  \
# 0     NaN     NaN     NaN     0.0     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     0.0     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     0.0     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     0.0     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#    Var179     Var180  Var181  Var182  Var183  Var184  Var185  Var186  Var187  \
# 0     NaN        NaN     0.0     NaN     NaN     NaN     NaN     NaN     NaN
# 1     NaN        NaN     0.0     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN        NaN    14.0     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN        NaN     0.0     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN  2892911.0     NaN     NaN     NaN     NaN     NaN     0.0     2.0
#
#    Var188  Var189  Var190 Var191      Var192   Var193 Var194 Var195 Var196  \
# 0     NaN     NaN     NaN    NaN  P1WvyxLp3Z  2Knk1KF    NaN   taul   1K8T
# 1     NaN     NaN     NaN    NaN  bZkvyxLkBI     RO12    NaN   taul   1K8T
# 2     NaN     NaN     NaN    NaN  75lTmBtFkL     RO12   SEuy   taul   1K8T
# 3     NaN     NaN     NaN    NaN  YddTmBtueT     RO12   SEuy   taul   1K8T
# 4     NaN     NaN     NaN    NaN  mCGq9ayE15     RO12    NaN   taul   1K8T
#
#   Var197   Var198      Var199   Var200 Var201 Var202 Var203 Var204 Var205  \
# 0   0Xwj  PHNvXy8  xUOdRmdN20  IBm9AvG    NaN   skcI   HLqf   vzJD    NaN
# 1   0Xwj  6KF0k8W  V4E_TU9097      NaN    NaN   CZsd   F3hy   vzJD   09_Q
# 2   AnrR  ckoNVBU  _jTP8ioIlJ  JnrRQD4   smXZ   PwdO   9_Y1   C6Eu   VpdQ
# 3   487l  77f44U8     II0S8f9  a1lFLoc   smXZ   SOkz   9_Y1   C6Eu   VpdQ
# 4   lK27  esxkA1P  767sa0XN9l      NaN    NaN   kVZt   9_Y1   vm5R   09_Q
#
#   Var206      Var207 Var208  Var209 Var210 Var211   Var212 Var213   Var214  \
# 0   lVqb  NKv3VA1BpP   sBgB     NaN   uKAI   L84s  Ie_5MZs    NaN  xRz9wph
# 1   IYzP  me75fM6ugJ   kIsH     NaN   uKAI   L84s  NhsEn4L    NaN      NaN
# 2   sYC_  me75fM6ugJ   kIsH     NaN   uKAI   Mtgm  NhsEn4L    NaN  Iy8LM_S
# 3   IYzP  me75fM6ugJ   kIsH     NaN   uKAI   L84s  NhsEn4L    NaN  GccbB3h
# 4    NaN  me75fM6ugJ   kIsH     NaN   uKAI   Mtgm  NhsEn4L    NaN      NaN
#
#   Var215   Var216 Var217 Var218 Var219   Var220 Var221   Var222      Var223  \
# 0    NaN  CWNY2py   jgOV   UYBR   FzaX  UF16siJ   zCkv  APgdzOv  jySVZNlOJy
# 1    NaN  TDcECyH   PDRj   cJvF   FzaX  ot6oLzk   oslk  IIvC99a  LM8l689qOp
# 2    NaN  kq0aHkC   laMb   UYBR   FzaX  6VLNqhB   oslk  6YSocsg  LM8l689qOp
# 3    NaN  mAjbk_S   qLRt   UYBR   FzaX  tzp8jNM   oslk  5nQ7A2G  jySVZNlOJy
# 4   eGzu  7Wwvby0   XqfQ   UYBR   FzaX  EPImS85   oslk  MI8s5nE  LM8l689qOp
#
#   Var224 Var225 Var226 Var227         Var228 Var229  Var230
# 0    NaN   ELof   xb3V   6fzt        Zy3gnGM    NaN     NaN
# 1    NaN    NaN   xb3V   RAYp  F2FyR07IdsN7I    NaN     NaN
# 2    NaN   kG3k   rgKb   RAYp  F2FyR07IdsN7I   mj86     NaN
# 3    NaN   kG3k   rgKb   RAYp  F2FyR07IdsN7I   am7c     NaN
# 4    NaN    NaN   7P5s   RAYp  F2FyR07IdsN7I    NaN     NaN

# %%
X_raw = churn_data_train.drop(columns = ['labels'])
y_raw = churn_data_train['labels']

X_dev_raw, X_val_raw, y_dev, y_val = train_test_split(X_raw, y_raw, stratify = y_raw, 
                                                      test_size = 0.1, random_state = SEED)

y_dev = y_dev.values
y_val = y_val.values

# %% [markdown]
# ### Data imputation

# %% [markdown]
# Определим вспомогательные функции для построения пайплайнов

# %%
def fillna_imputer(df):
    '''
    Заменяет Nan значения на строковый маркер 'Nan' и добавляет boolean столбец для каждого признака
    '''
    column_names = df.columns.to_list()
    result = pd.DataFrame()
    for name in column_names:
        result[name] = df[name].fillna(value = 'Nan')
        result[name + '_bool'] = df[name].isna()
    return result.reset_index(drop = True)

bool_fillna_imputer = FunctionTransformer(fillna_imputer, validate=False)

# %%
def make_df_from_np(X, column_names):
    '''
    Восстанавливает датафрейм из numpy матрицы после масштабирования данных
    '''
    return pd.DataFrame(X, columns = column_names)

repair_df = FunctionTransformer(make_df_from_np, validate=False)

# %% [markdown]
# Определим ключевые элементы общего пайплайна

# %%
num_pipeline = Pipeline([
    ('selector', DataFrameSelector(useful_num_featues)),
    ('imputer', SimpleImputer(strategy = 'mean')),
    ('std_scaler', StandardScaler()),
    ('repair_df', repair_df)
])


# https://ig248.gitlab.io/post/2018-11-21-transformer-factory/
# Как изменять параметры функций внутри пайплайна
num_pipeline = num_pipeline.set_params(repair_df__kw_args={'column_names': useful_num_featues})

# %%
cat_pipeline = Pipeline([
    ('selector', DataFrameSelector(useful_cat_featues)),
    ('bool_fillna_imputer', bool_fillna_imputer),
    ('label_encoder', ce.CatBoostEncoder(random_state = SEED)) 
])

# %%
full_pipeline = DFFeatureUnion(transformer_list = [
    ('num_pipeline', num_pipeline),
    ('cat_pipeline', cat_pipeline)
],
                            n_jobs = -1)

# %%
X_dev = full_pipeline.fit_transform(X_dev_raw, y_dev)
X_val = full_pipeline.transform(X_val_raw)
X_test = full_pipeline.transform(churn_data_test)

print('X_dev shape: {}, X_val shape: {}, X_test shape: {}'.format(X_dev.shape, X_val.shape, X_test.shape))
# Out:
# X_dev shape: (16469, 201), X_val shape: (1830, 201), X_test shape: (10000, 201)

# %% [markdown]
# ## Naive model

# %%
def plot_roc_curve(fpr, tpr, label = None):
    plt.plot(fpr, tpr, linewidth = 2, label = label)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.axis([0, 1, 0, 1])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')

# %%
def make_csv_predictions(predictions, path = None):
    df = pd.DataFrame({'ID': range(0, len(predictions)), 'result': predictions})
    if path is not None:
        df.to_csv(path, sep = ',', index = False)
    else:
        return df

# %%
# def plot_confusion_matrix(y_true, y_pred ):
#     matrix = confusion_matrix(y_true, y_pred)
#     annot_kws = {"ha": 'left',"va": 'center'}
#     sns.heatmap(matrix, annot=True, cbar=False, annot_kws=annot_kws)
#     plt.ylabel('True Label')
#     plt.xlabel('Predicted Label')

# %%
naive_result = train_model_cv_cl(X_dev, y_dev, X_test, 
                                 model_type = 'sklearn', eval_metric = 'auc', 
                                 sk_model = LogisticRegression,
                                 params = {'solver': 'lbfgs', 
                                           'max_iter': 1000, 
                                           'n_jobs': -1})
# Out:
# Fold 0. auc: 0.926641.
# Fold 1. auc: 0.924500.
# Fold 2. auc: 0.950428.
# Fold 3. auc: 0.939320.
# Fold 4. auc: 0.938692.
# CV mean score: 0.935916, std: 0.009447.

# %%
naive_result.keys()
# Out:
# dict_keys(['predictions', 'overall_val_predictions', 'cv_scores'])

# %%
fpr, tpr, thresholds = roc_curve(y_dev, naive_result['overall_val_predictions'])

# %%
plot_roc_curve(fpr, tpr)

# %%
skplt.metrics.plot_confusion_matrix(y_dev, np.around(naive_result['overall_val_predictions']), figsize=(7,5))
plt.show()

# %%
make_csv_predictions(naive_result['predictions'], path = './Kaggle_predictions/naive_logistic.csv')

#score - 0.61071

# %% [markdown]
# ## Feature engineering

# %%
default_cat_results = train_model_cv_cl(X_dev, y_dev.astype('int'), X_test, 
                                                        model_type = 'cat', eval_metric = 'auc', 
                                                        params = {})
# Out:
# Learning rate set to 0.102288
# 0:	test: 0.8772054	best: 0.8772054 (0)	total: 28.7ms	remaining: 28.7s
# 250:	test: 0.9695410	best: 0.9696773 (195)	total: 7.85s	remaining: 23.4s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.9696773135
# bestIteration = 195
#
# Shrink model to first 196 iterations.
# Learning rate set to 0.102288
# 0:	test: 0.6912715	best: 0.6912715 (0)	total: 32.6ms	remaining: 32.5s
# 250:	test: 0.9643848	best: 0.9646085 (183)	total: 6.69s	remaining: 20s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.9646085294
# bestIteration = 183
#
# Shrink model to first 184 iterations.
# Learning rate set to 0.102288
# 0:	test: 0.5070333	best: 0.5070333 (0)	total: 15.9ms	remaining: 15.9s
# 250:	test: 0.9738870	best: 0.9741226 (131)	total: 8.2s	remaining: 24.5s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.9741225934
# bestIteration = 131
#
# Shrink model to first 132 iterations.
# Learning rate set to 0.102288
# 0:	test: 0.7643379	best: 0.7643379 (0)	total: 27.6ms	remaining: 27.5s
# 250:	test: 0.9700559	best: 0.9702558 (240)	total: 7.77s	remaining: 23.2s
# 500:	test: 0.9697064	best: 0.9704636 (429)	total: 15.4s	remaining: 15.4s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.9704636435
# bestIteration = 429
#
# Shrink model to first 430 iterations.
# Learning rate set to 0.102289
# 0:	test: 0.8228207	best: 0.8228207 (0)	total: 31.8ms	remaining: 31.8s
# 250:	test: 0.9706298	best: 0.9707694 (218)	total: 7.44s	remaining: 22.2s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.9707693903
# bestIteration = 218
#
# Shrink model to first 219 iterations.
# CV mean score: 0.969928, std: 0.003064.

# %%
make_csv_predictions(default_cat_results['predictions'], path = './Kaggle_predictions/default_catboost.csv')

#score - 0.58379
